# %%
import random

def print_board(board):
    for row in board:
        print(' | '.join(row))
        print('---------')

def check_winner(board):
    for row in board:
        if row[0] == row[1] == row[2] != ' ':
            return row[0]

    for col in range(3):
        if board[0][col] == board[1][col] == board[2][col] != ' ':
            return board[0][col]

    if board[0][0] == board[1][1] == board[2][2] != ' ':
        return board[0][0]
    if board[0][2] == board[1][1] == board[2][0] != ' ':
        return board[0][2]

    return None

def is_board_full(board):
    for row in board:
        if ' ' in row:
            return False
    return True

def make_random_move(board):
    while True:
        row = random.randint(0, 2)
        col = random.randint(0, 2)
        if board[row][col] == ' ':
            return row, col

def play_game():
    board = [[' ' for _ in range(3)] for _ in range(3)]
    current_player = 'X'

    while True:
        print_board(board)

        if current_player == 'X':
            row, col = make_random_move(board)
            print('AI player X chooses', row, col)
        else:
            row, col = make_random_move(board)
            print('AI player O chooses', row, col)

        board[row][col] = current_player

        winner = check_winner(board)
        if winner:
            print_board(board)
            if current_player == 'X':
                print('AI player X wins!')
            else:
                print('AI player O wins!')
            break

        if is_board_full(board):
            print_board(board)
            print("It's a tie!")
            break

        current_player = 'O' if current_player == 'X' else 'X'

play_game()
# Out:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# AI player X chooses 1 1
#   |   |
# ---------
#   | X |
# ---------
#   |   |
# ---------
# AI player O chooses 1 2
#   |   |
# ---------
#   | X | O
# ---------
#   |   |
# ---------
# AI player X chooses 1 0
#   |   |
# ---------
# X | X | O
# ---------
#   |   |
# ---------
# AI player O chooses 2 1
#   |   |
# ---------
# X | X | O
# ---------
#   | O |
# ---------
# AI player X chooses 0 0
# X |   |
# ---------
# X | X | O
# ---------
#   | O |
# ---------
# AI player O chooses 2 2
# X |   |
# ---------
# X | X | O
# ---------
#   | O | O
# ---------
# AI player X chooses 0 2
# X |   | X
# ---------
# X | X | O
# ---------
#   | O | O
# ---------
# AI player O chooses 2 0
# X |   | X
# ---------
# X | X | O
# ---------
# O | O | O
# ---------
# AI player O wins!
